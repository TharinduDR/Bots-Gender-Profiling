# %%
from random import seed

import pandas as pd
from sklearn.model_selection import train_test_split



print("Start executing")
seed(726)

pre_train = pd.read_csv("data/pan_data_en.tsv", sep='\t')

rows = []
for index, row in pre_train.iterrows():
    for tweet in row['text'].split(", '"):
        if len(tweet.split()) > 3:
            if row['humanBot'] == "[bot]":
                new_row = [row['index'], "bot", row['sex'], tweet]
            else:
                new_row = [row['index'], row['humanBot'], row['sex'], tweet]
            rows.append(new_row)

header = ["id", "human", "gender", "tweet"]

train_full = pd.DataFrame(rows, columns=header)

train, test = train_test_split(train_full, test_size=0.2)

train.to_csv("data/train_en.tsv", sep='\t', encoding='utf-8')
test.to_csv("data/test_en.tsv", sep='\t', encoding='utf-8')

print("finished executing")
# Out:
# Start executing
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# bot
# finished executing

# %%
train[:5]
# Out:
#                                       id  human  gender  \
# 212717  ae5956bd7e744601958008c9514cf1d6  human    male
# 320629  ff8c26db7278a3b51dba5e5db3f1d1ac  human  female
# 317601  fdbc9215acb1c676b4592987867c04b8  human  female
# 230018  b9781bb0eebf3143367f245f4fbad019    bot     bot
# 112325  6586c6858b0aab51410eab76b693714d    bot     bot
#
#                                                     tweet
# 212717  Mobile usability: have useful help screens htt...
# 320629  Private VIP Access to Inner-Circle, Top-Secret...
# 317601       The Grinch in chief https://t.co/LhUkvXyAfr'
# 230018                    Grubby Protesters. Not Honest!'
# 112325  A business has to be involving, it has to be f...

# %%
from random import seed

import pandas as pd
from sklearn.model_selection import train_test_split



print("Start executing")
seed(726)

pre_train = pd.read_csv("data/pan_data_en.tsv", sep='\t')

rows = []
for index, row in pre_train.iterrows():
    for tweet in row['text'].split(", '"):
        if len(tweet.split()) > 3:
            if row['humanBot'] == "[bot]":
               continue
            if row['humanBot'] == "bot":
               continue
            else:
                new_row = [row['index'], row['humanBot'], row['sex'], tweet]
            rows.append(new_row)

header = ["id", "human", "gender", "tweet"]

train_full = pd.DataFrame(rows, columns=header)

train, test = train_test_split(train_full, test_size=0.2)

train.to_csv("data/train_gender_en.tsv", sep='\t', encoding='utf-8')
test.to_csv("data/test_gender_en.tsv", sep='\t', encoding='utf-8')

print("finished executing")
# Out:
# Start executing
# finished executing

# %%
train[:5]
# Out:
#                                       id  human  gender  \
# 114531  bdda1c2944c5f9872361ab7b5c5320cb  human    male
# 46421   5776d9eb6c5d1e3de13669717394aac4  human    male
# 9345    1d50b53bef7c27c8fc0042707c0a4f94  human    male
# 28823   3af4cc9b03a55c55028cdf06bdd50701  human  female
# 4358    1575e6912b5ded0eea725df87315174a  human    male
#
#                                                     tweet
# 114531  @philford @travelling_wolf I could tell you th...
# 46421      love the water colour https://t.co/7u88fwNs8X'
# 9345    DAY 313: DO YOU KNOW HOW MUCH IVORY COMES THRO...
# 28823   @Aoife_Dooley Can you leave stuff in your Nana...
# 4358    “@BBCSport: Crystal Palace in talks to re-sign...
